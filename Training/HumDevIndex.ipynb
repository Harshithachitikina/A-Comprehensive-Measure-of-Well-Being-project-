# %%
# Importing the libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots inside the notebook
# %matplotlib inline

# %%
import pandas as pd

Development = pd.read_csv("../Dataset/HDI.csv")

# %%
Development.head()
Development.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 124 entries, 0 to 123
# Data columns (total 6 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Country                                 124 non-null    str
#  1   Life expectancy                         124 non-null    float64
#  2   Mean years of schooling                 124 non-null    float64
#  3   Expected years of schooling             124 non-null    float64
#  4   Gross National Income (GNI) per capita  124 non-null    int64
#  5   HDI                                     124 non-null    float64
# dtypes: float64(4), int64(1), str(1)
# memory usage: 5.9 KB

# %%
Development.head()
# Out:
#        Country  Life expectancy  Mean years of schooling  \
# 0       Norway             82.6                     12.9
# 1  Switzerland             84.3                     13.9
# 2      Ireland             82.8                     12.7
# 3      Germany             81.3                     14.1
# 4    Hong Kong             85.5                     12.2
#
#    Expected years of schooling  Gross National Income (GNI) per capita    HDI
# 0                         18.2                                   66000  0.960
# 1                         16.5                                   70000  0.966
# 2                         19.7                                   68371  0.974
# 3                         17.1                                   47000  0.939
# 4                         17.3                                   62967  0.955

# %%
Development.tail()
# Out:
#       Country  Life expectancy  Mean years of schooling  \
# 119  Cambodia             70.0                      5.0
# 120      Laos             67.3                      5.0
# 121   Myanmar             67.1                      5.0
# 122    Brunei             76.0                      9.5
# 123      Fiji             67.6                     10.5
#
#      Expected years of schooling  Gross National Income (GNI) per capita  \
# 119                         11.0                                    4000
# 120                         11.0                                    7000
# 121                         10.0                                    5000
# 122                         14.0                                   65000
# 123                         13.5                                    9500
#
#        HDI
# 119  0.587
# 120  0.604
# 121  0.575
# 122  0.841
# 123  0.715

# %%
Development.shape
# Out:
# (124, 6)

# %%
Development.columns
# Out:
# Index(['Country', 'Life expectancy', 'Mean years of schooling',
#        'Expected years of schooling', 'Gross National Income (GNI) per capita',
#        'HDI'],
#       dtype='str')

# %%
Development.describe()
# Out:
#        Life expectancy  Mean years of schooling  Expected years of schooling  \
# count       124.000000               124.000000                    124.00000
# mean         74.086290                 9.203226                     13.83871
# std           7.515278                 3.190584                      3.30168
# min          53.100000                 1.800000                      5.40000
# 25%          69.625000                 7.150000                     11.57500
# 50%          75.750000                 9.500000                     14.00000
# 75%          80.100000                12.125000                     16.40000
# max          85.500000                14.100000                     21.90000
#
#        Gross National Income (GNI) per capita         HDI
# count                              124.000000  124.000000
# mean                             23388.129032    0.750306
# std                              21328.989380    0.160610
# min                                800.000000    0.365000
# 25%                               5900.000000    0.639750
# 50%                              14500.000000    0.773500
# 75%                              37378.750000    0.882500
# max                              92000.000000    0.986000

# %%
Development.isnull().sum()
# Out:
# Country                                   0
# Life expectancy                           0
# Mean years of schooling                   0
# Expected years of schooling               0
# Gross National Income (GNI) per capita    0
# HDI                                       0
# dtype: int64

# %%
Development.dtypes
# Out:
# Country                                       str
# Life expectancy                           float64
# Mean years of schooling                   float64
# Expected years of schooling               float64
# Gross National Income (GNI) per capita      int64
# HDI                                       float64
# dtype: object

# %%
data1 = Development.head(20)

# %%
Development["Country"].unique()
# Out:
# <StringArray>
# [     'Norway', 'Switzerland',     'Ireland',     'Germany',   'Hong Kong',
#    'Australia',     'Iceland',      'Sweden',   'Singapore', 'Netherlands',
#  ...
#        'Haiti',        'Cuba',     'Jamaica',      'Panama',    'Mongolia',
#     'Cambodia',        'Laos',     'Myanmar',      'Brunei',        'Fiji']
# Length: 124, dtype: str

# %%
plt.figure(figsize=(10,5))

sns.stripplot(
    x="Mean years of schooling",
    y="HDI",
    data=data1,
    jitter=True
)

plt.xticks(rotation=90)
plt.title("Mean Years of Schooling vs HDI")

plt.show()

# %%
plt.figure(figsize=(10,5))

sns.stripplot(
    x="Life expectancy",
    y="HDI",
    data=data1,
    jitter=True
)

plt.xticks(rotation=90)
plt.title("Life Expectancy vs HDI")

plt.show()

# %%
heat = Development.select_dtypes(include=["number"])

plt.figure(figsize=(8,6))

sns.heatmap(
    heat.corr(),
    annot=True,
    cmap="coolwarm"
)

plt.title("Correlation Heatmap")

plt.show()

# %%
X = Development[
    [
        "Life expectancy",
        "Mean years of schooling",
        "Expected years of schooling",
        "Gross National Income (GNI) per capita"
    ]
]

X.head()
# Out:
#    Life expectancy  Mean years of schooling  Expected years of schooling  \
# 0             82.6                     12.9                         18.2
# 1             84.3                     13.9                         16.5
# 2             82.8                     12.7                         19.7
# 3             81.3                     14.1                         17.1
# 4             85.5                     12.2                         17.3
#
#    Gross National Income (GNI) per capita
# 0                                   66000
# 1                                   70000
# 2                                   68371
# 3                                   47000
# 4                                   62967

# %%
Y = Development["HDI"]

Y.head()
# Out:
# 0    0.960
# 1    0.966
# 2    0.974
# 3    0.939
# 4    0.955
# Name: HDI, dtype: float64

# %%
print("X Shape:", X.shape)
print("Y Shape:", Y.shape)
# Out:
# X Shape: (124, 4)
# Y Shape: (124,)

# %%
X.isnull().sum()
# Out:
# Life expectancy                           0
# Mean years of schooling                   0
# Expected years of schooling               0
# Gross National Income (GNI) per capita    0
# dtype: int64

# %%
X.fillna(X.mean(), inplace=True)
# Out:
#      Life expectancy  Mean years of schooling  Expected years of schooling  \
# 0               82.6                     12.9                         18.2
# 1               84.3                     13.9                         16.5
# 2               82.8                     12.7                         19.7
# 3               81.3                     14.1                         17.1
# 4               85.5                     12.2                         17.3
# ..               ...                      ...                          ...
# 119             70.0                      5.0                         11.0
# 120             67.3                      5.0                         11.0
# 121             67.1                      5.0                         10.0
# 122             76.0                      9.5                         14.0
# 123             67.6                     10.5                         13.5
#
#      Gross National Income (GNI) per capita
# 0                                     66000
# 1                                     70000
# 2                                     68371
# 3                                     47000
# 4                                     62967
# ..                                      ...
# 119                                    4000
# 120                                    7000
# 121                                    5000
# 122                                   65000
# 123                                    9500
#
# [124 rows x 4 columns]

# %%
X.fillna(X.mean(), inplace=True)
# Out:
#      Life expectancy  Mean years of schooling  Expected years of schooling  \
# 0               82.6                     12.9                         18.2
# 1               84.3                     13.9                         16.5
# 2               82.8                     12.7                         19.7
# 3               81.3                     14.1                         17.1
# 4               85.5                     12.2                         17.3
# ..               ...                      ...                          ...
# 119             70.0                      5.0                         11.0
# 120             67.3                      5.0                         11.0
# 121             67.1                      5.0                         10.0
# 122             76.0                      9.5                         14.0
# 123             67.6                     10.5                         13.5
#
#      Gross National Income (GNI) per capita
# 0                                     66000
# 1                                     70000
# 2                                     68371
# 3                                     47000
# 4                                     62967
# ..                                      ...
# 119                                    4000
# 120                                    7000
# 121                                    5000
# 122                                   65000
# 123                                    9500
#
# [124 rows x 4 columns]

# %%
X.isnull().sum()
# Out:
# Life expectancy                           0
# Mean years of schooling                   0
# Expected years of schooling               0
# Gross National Income (GNI) per capita    0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()

# %%
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y,
    test_size=0.1,
    random_state=42
)

# %%
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (111, 4)
# (13, 4)
# (111,)
# (13,)

# %%
from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
Y_pred = reg.predict(X_test)

print(Y_pred)
# Out:
# [0.92706366 0.8164352  0.83719021 0.41753682 0.70174921 0.70820116
#  0.71396133 0.81201576 0.55967708 0.96308285 0.88938343 0.57731607
#  0.75939529]

# %%
print(Y_test)
# Out:
# 18     0.924
# 42     0.825
# 36     0.847
# 76     0.388
# 53     0.718
# 90     0.731
# 56     0.714
# 122    0.841
# 121    0.575
# 4      0.955
# 27     0.895
# 101    0.548
# 44     0.778
# Name: HDI, dtype: float64

# %%
comparison = pd.DataFrame({
    "Actual HDI": Y_test.values,
    "Predicted HDI": Y_pred
})

comparison
# Out:
#     Actual HDI  Predicted HDI
# 0        0.924       0.927064
# 1        0.825       0.816435
# 2        0.847       0.837190
# 3        0.388       0.417537
# 4        0.718       0.701749
# 5        0.731       0.708201
# 6        0.714       0.713961
# 7        0.841       0.812016
# 8        0.575       0.559677
# 9        0.955       0.963083
# 10       0.895       0.889383
# 11       0.548       0.577316
# 12       0.778       0.759395

# %%
from sklearn.metrics import r2_score

r2 = r2_score(Y_test, Y_pred)
print("R² Score:", r2)
# Out:
# R² Score: 0.98694050430741

# %%
from sklearn.metrics import mean_squared_error

mse = mean_squared_error(Y_test, Y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 0.00032404596209633697

# %%
import numpy as np

rmse = np.sqrt(mse)

print("Root Mean Squared Error =", rmse)
# Out:
# Root Mean Squared Error = 0.01800127667962295

# %%
sample = [[72.0, 8.5, 13.5, 15000]]

prediction = reg.predict(sample)

print("Predicted HDI =", prediction[0])
# Out:
# Predicted HDI = 0.7111945458263103
# c:\Users\chhar\OneDrive\Desktop\A-Comprehensive-Measure-of-Well-Being\.venv\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
with open("../Flask/HDI.pkl", "wb") as file:
    pickle.dump(reg, file)
